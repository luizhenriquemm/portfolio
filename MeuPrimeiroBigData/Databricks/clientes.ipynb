# %%
import random
import datetime
import unicodedata
from pyspark.sql.types import StructType, StructField, StringType, DateType, IntegerType

def remove_acento(s):
   return ''.join(c for c in unicodedata.normalize('NFD', s)
                  if unicodedata.category(c) != 'Mn')

def cria_cliente(id):
# Geração de campos

  ## Sexo
  opcoes = ["Masculino", "Feminino"]
  sexo = random.choice(opcoes)

  ## Nome
  if (sexo == "Masculino"):
    opcoes1 = ["Pedro", "João", "Enzo", "Davi", "Carlos", "Luiz", "Victor", "Júlio", "Marcos", "Marco", "Artur", "Lucas", "Paulo", 
               "Mateus", "Daniel", "Emanuel", "Thiago", "Danilo", "David", "Guilherme", "Douglas", "Rafael", "José", "Leonardo", 
               "Pedro Henrique", "João Pedro", "Jão Miguel", "Enzo Gabriel", "Davi Lucas", "João Vitor", "Carlos Eduardo", "João Lucas", 
               "João Victor", "João Gabriel", "Luiz Felipe", "Luiz Henrique", "Luiz Miguel", "Victor Hugo", "João Guilherme", 
               "Júlio César", "Marcos Vínicius", "João Paulo", "Pedro Lucas", "Marco Antônio", "Paulo Henrique", "Luiz Gustavo", 
               "Lucas Gabriel", "Luiz Fernando", "Pedro Miguel", "Luiz Otávio"]

  if (sexo == "Feminino"):
    opcoes1 = ["Maria", "Alice", "Júlia", "Helena", "Mariana", "Beatriz", "Laura", "Larissa", "Cecília", "Ana", "Ester", "Yasmin", 
               "Catarina", "Eloá", "Sofia", "Lívia", "Sara", "Rebeca", "Juliana", "Camila", "Fernanda", "Letícia", "Sophia", "Raquel", 
               "Adriele", "Talita", "Marta", "Abigail", "Maria Eduarda", "Ana Clara", "Maria Clara", "Maria Luíza", "Ana Beatriz", 
               "Ana Júlia", "Ana Luíza", "Maria Júlia", "Ana Carolina", "Maria Alice", "Maria Cecília", "Ana Paula", "Maria Fernanda", 
               "Ana Laura", "Maria Helena", "Ana Alice", "Maria Vitória", "Maria Luísa", "Ana Vitória", "Maria Flor", "Maria Laura", 
               "Ana Sofia", "Maria Valentina", "Ana Cecília", "Maria Heloísa", "Maria Elisa"]

  nome = random.choice(opcoes1)

  ## Sobrenome
  opcoes2 = ["Almeida", "Alves", "Andrade", "Barbosa", "Barros", "Batista", "Borges", "Campos", "Cardoso", "Carvalho", "Castro", 
             "Costa", "Dias", "Duarte", "Freitas", "Fernandes", "Ferreira", "Garvcia", "Gomes", "Gonçalves", "Lima", "Lopes", "Machado", 
             "Marques", "Martins", "Medeiros", "Melo", "Mendes", "Miranda", "Monteiro", "Moraes", "Moreira", "Moura", "Nascimento", 
             "Nunes", "Oliveira", "Pereira", "Ramos", "Reis", "Ribeiro", "Rocha", "Santana", "Santos", "Silva", "Soares", "Souza", 
             "Teixeira", "Vieira"]

  sobrenome = random.choice(opcoes2)

  ## Email
  opcoes = ["@gmail.com", "@hotmail.com", "@outlook.com.br"]

  email = remove_acento(nome.lower().replace(" ", ".")) + "." + remove_acento(sobrenome.lower()) + random.choice(opcoes)

  ## Endereço
  opcoes1 = ["Avenida", "Rua", "Estrada"]
  opcoes2 = ["Santos Dumont", "Tiradentes", "Sao Francisco", "Castro Alves", "Duque de Caxias", "Rui Barbosa", "José Bonifácio", 
             "Dom Pedro I", "Dom Pedro II", "São Luiz", "Santa Rita", "Santo Antonio", "São Pedro", "São João", "São Sebastião", 
             "Santa Luzia", "São Jorge", "São José", "São Paulo", "Brasil", "Rio de Janeiro", "Santa Catarina", "Paraná", "Minas Gerais",
             "Espirito Santo", "Goías", "Ceará", "Belo Horizonte", "Pernambuco", "Piauí", "Mato Grosso", "Pará"]

  endereco = random.choice(opcoes1) + " " + random.choice(opcoes2) + ", " + str(random.choice(range(1, 5000)))

  ## Cidade e Estado
  opcoes1 = [
    {"uf": "PR", "estado": "Paraná"},
    {"uf": "SP", "estado": "São Paulo"},
    {"uf": "RJ", "estado": "Rio de Janeiro"},
    {"uf": "SC", "estado": "Santa Catarina"},
    {"uf": "MS", "estado": "Mato Grosso do Sul"}
  ]

  opcoes2 = {
    "PR": [{"cidade": "Curitiba", "ddd": "41"}, {"cidade": "Maringá", "ddd": "44"}, {"cidade": "Londrina", "ddd": "43"}, 
          {"cidade": "Umuarama", "ddd": "44"}, {"cidade": "Cascavel", "ddd": "45"}],
    "SP": [{"cidade": "São Paulo", "ddd": "11"}, {"cidade": "Campinas", "ddd": "19"}, {"cidade": "Ourinhos", "ddd": "14"}, 
          {"cidade": "Marília", "ddd": "14"}, {"cidade": "São José do Rio Preto", "ddd": "17"}],
    "RJ": [{"cidade": "Rio de Janeiro", "ddd": "21"}, {"cidade": "Duque de Caixas", "ddd": "21"}, {"cidade": "Volta Redonda", "ddd": "24"}, 
          {"cidade": "Teresópolis", "ddd": "21"}, {"cidade": "Nova Friburgo", "ddd": "22"}],
    "SC": [{"cidade": "Blumenau", "ddd": "47"}, {"cidade": "Florianópolis", "ddd": "48"}, {"cidade": "Tubarão", "ddd": "48"}, 
          {"cidade": "Chapecó", "ddd": "49"}, {"cidade": "Concordia", "ddd": "49"}],
    "MS": [{"cidade": "Dourados", "ddd": "67"}, {"cidade": "Campo Grande", "ddd": "67"}, {"cidade": "Nova Andradina", "ddd": "67"}, 
          {"cidade": "Três Lagoas", "ddd": "67"}, {"cidade": "Paranaiba", "ddd": "67"}]
  }

  escolha = random.choice(opcoes1)
  uf = escolha["uf"]
  estado = escolha["estado"]
  escolha = random.choice(opcoes2[uf])
  ddd = escolha["ddd"]
  cidade = escolha["cidade"]

  ## Telefone
  telefone = "(" + ddd + ") " + str(random.choice(range(8, 9))) + ''.join([str(random.choice(range(1, 9))) for i in range(3)]) + "-" + ''.join([str(random.choice(range(1, 9))) for i in range(4)])

  ## CPF
  cpf, v1, v2 = ["", 0, 0]
  for n in range(9):
    d = random.choice(range(1,9))
    cpf = cpf + str(d)

    v1 = v1 + (d * (10 - n))
    v2 = v2 + (d * (11 - n))

  cpf = cpf + str(0 if (v1 * 10 % 11) == 10 else v1 * 10 % 11)
  cpf = cpf + str(0 if (v2 * 10 % 11) == 10 else v2 * 10 % 11)
  cpf = cpf[0:3] + "." + cpf[3:6] + "." + cpf[6:9] + "-" + cpf[9:11]

  ## Data Nascimento
  data_nascimento = datetime.date(1960,1,1) + datetime.timedelta(seconds=random.randint(0, int((datetime.date(2002,1,1) - datetime.date(1960,1,1)).total_seconds())))
  
  ## Estado civil
  opcoes = ["Solteiro(a)", "Casado(a)", "Divorciado(a)", "Viuvo(a)"]
  estado_civil = random.choice(opcoes)
  
  ## Escolaridade
  opcoes = ["Ensino fundamental incompleto", "Ensino fundamental completo", "Ensino médio incompleto", "Ensino médio completo", "Ensino superior incompleto", "Ensino superior completo", "Mestrado", "Doutorado"]
  escolaridade = random.choice(opcoes)
  
  return [id, nome, sobrenome, sexo, email, endereco, estado, cidade, telefone, cpf, data_nascimento, estado_civil, escolaridade]

  

schema = StructType([
  StructField('id', IntegerType(), True),
  StructField('nome', StringType(), True),
  StructField('sobrenome', StringType(), True),
  StructField('sexo', StringType(), True),
  StructField('email', StringType(), True),
  StructField('endereco', StringType(), True),
  StructField('estado', StringType(), True),
  StructField('cidade', StringType(), True),
  StructField('telefone', StringType(), True),
  StructField('cpf', StringType(), True),
  StructField('data_nascimento', DateType(), True),
  StructField('estado_civil', StringType(), True),
  StructField('escolaridade', StringType(), True)
])
    
clientes = spark.createDataFrame(sc.parallelize([cria_cliente(i) for i in range(1, 10000)]), schema)
clientes.printSchema()
  
print (clientes.count())

#df.write.option('driver', 'org.postgresql.Driver').jdbc("exercicio.crb23nbjpep1.us-east-1.rds.amazonaws.com", table, mode, properties)

clientes.write \
    .jdbc("jdbc:postgresql://exercicio.crb23nbjpep1.us-east-1.rds.amazonaws.com/exercicio", "public.clientes", "overwrite",
          {"user": "postgres", "password": "wy8JcHQh4rypF4A"})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- id: integer (nullable = true)
# -- nome: string (nullable = true)
# -- sobrenome: string (nullable = true)
# -- sexo: string (nullable = true)
# -- email: string (nullable = true)
# -- endereco: string (nullable = true)
# -- estado: string (nullable = true)
# -- cidade: string (nullable = true)
# -- telefone: string (nullable = true)
# -- cpf: string (nullable = true)
# -- data_nascimento: date (nullable = true)
# -- estado_civil: string (nullable = true)
# -- escolaridade: string (nullable = true)
#
# 9999
# </div>
